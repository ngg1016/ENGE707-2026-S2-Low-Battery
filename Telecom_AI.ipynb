# %%
print("Python testing")
#Basic test script to ensure Python environment is functional
# Out:
# Python testing

# %%
import pandas as pd

df = pd.read_csv(
    "telecom_customer_churn.csv",
    header=None,
    na_values="?"
)

print("Raw shape of dataset: ", df.shape)
print(df.head())

#Import pandas to allow reading of dataset file, print out the rows and columns/shape of it.
# Out:
# Raw shape of dataset:  (7044, 38)
#             0       1    2        3                     4             5   \
# 0  Customer ID  Gender  Age  Married  Number of Dependents          City
# 1   0002-ORFBO  Female   37      Yes                     0  Frazier Park
# 2   0003-MKNFE    Male   46       No                     0      Glendale
# 3   0004-TLHLJ    Male   50       No                     0    Costa Mesa
# 4   0011-IGKFF    Male   78      Yes                     0      Martinez
#
#          6          7            8                    9   ...  \
# 0  Zip Code   Latitude    Longitude  Number of Referrals  ...
# 1     93225  34.827662  -118.999073                    2  ...
# 2     91206  34.162515  -118.203869                    0  ...
# 3     92627  33.645672  -117.922613                    0  ...
# 4     94553  38.014457  -122.115432                    1  ...
#
#                 28              29             30             31  \
# ...
