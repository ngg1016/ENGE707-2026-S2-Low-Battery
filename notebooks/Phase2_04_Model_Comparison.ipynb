# %% [markdown]
# # Phase II: Conventional Model Comparison

# %% [markdown]
# ## 1. Load Preprocessed Dataset

# %%
import pandas as pd

train_data = pd.read_csv(
    "../data/feature_engineered/telecom_train_preprocessed_all_features.csv"
)

test_data = pd.read_csv(
    "../data/feature_engineered/telecom_test_preprocessed_all_features.csv"
)

X_train = train_data.drop(
    columns=["Churn Target"]
)

y_train = train_data["Churn Target"]

X_test = test_data.drop(
    columns=["Churn Target"]
)

y_test = test_data["Churn Target"]

print(X_train.shape)
print(X_test.shape)
# Out:
# (8278, 34)
# (1409, 34)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    balanced_accuracy_score
)

# %% [markdown]
# ## 2. Logistic Regression

# %%
logistic_model = LogisticRegression(
    max_iter=2000,
    random_state=42
)

logistic_model.fit(
    X_train,
    y_train
)

logistic_predictions = logistic_model.predict(
    X_test
)

logistic_accuracy = accuracy_score(
    y_test,
    logistic_predictions
)

logistic_precision = precision_score(
    y_test,
    logistic_predictions,
    zero_division=0
)

logistic_recall = recall_score(
    y_test,
    logistic_predictions,
    zero_division=0
)

logistic_f1 = f1_score(
    y_test,
    logistic_predictions,
    zero_division=0
)

logistic_balanced_accuracy = (
    balanced_accuracy_score(
        y_test,
        logistic_predictions
    )
)

print("Logistic Regression Complete")
# Out:
# Logistic Regression Complete
# c:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 2000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=2000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## 3. Decision Tree

# %%
decision_tree_model = DecisionTreeClassifier(
    random_state=42
)

decision_tree_model.fit(
    X_train,
    y_train
)

decision_tree_predictions = (
    decision_tree_model.predict(X_test)
)

decision_tree_accuracy = accuracy_score(
    y_test,
    decision_tree_predictions
)

decision_tree_precision = precision_score(
    y_test,
    decision_tree_predictions,
    zero_division=0
)

decision_tree_recall = recall_score(
    y_test,
    decision_tree_predictions,
    zero_division=0
)

decision_tree_f1 = f1_score(
    y_test,
    decision_tree_predictions,
    zero_division=0
)

decision_tree_balanced_accuracy = (
    balanced_accuracy_score(
        y_test,
        decision_tree_predictions
    )
)

print("Decision Tree Complete")
# Out:
# Decision Tree Complete

# %% [markdown]
# ## 4. Random Forest

# %%
random_forest_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

random_forest_model.fit(
    X_train,
    y_train
)

random_forest_predictions = (
    random_forest_model.predict(X_test)
)

random_forest_accuracy = accuracy_score(
    y_test,
    random_forest_predictions
)

random_forest_precision = precision_score(
    y_test,
    random_forest_predictions,
    zero_division=0
)

random_forest_recall = recall_score(
    y_test,
    random_forest_predictions,
    zero_division=0
)

random_forest_f1 = f1_score(
    y_test,
    random_forest_predictions,
    zero_division=0
)

random_forest_balanced_accuracy = (
    balanced_accuracy_score(
        y_test,
        random_forest_predictions
    )
)

print("Random Forest Complete")
# Out:
# Random Forest Complete

# %% [markdown]
# ## 5. Model Comparison

# %%
comparison_table = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        logistic_accuracy,
        decision_tree_accuracy,
        random_forest_accuracy
    ],
    "Precision": [
        logistic_precision,
        decision_tree_precision,
        random_forest_precision
    ],
    "Recall": [
        logistic_recall,
        decision_tree_recall,
        random_forest_recall
    ],
    "F1 Score": [
        logistic_f1,
        decision_tree_f1,
        random_forest_f1
    ],
    "Balanced Accuracy": [
        logistic_balanced_accuracy,
        decision_tree_balanced_accuracy,
        random_forest_balanced_accuracy
    ]
})

comparison_table
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic Regression  0.739532   0.505942  0.796791  0.618899
# 1        Decision Tree  0.761533   0.551913  0.540107  0.545946
# 2        Random Forest  0.836054   0.703704  0.660428  0.681379
#
#    Balanced Accuracy
# 0           0.757816
# 1           0.690826
# 2           0.779972

# %%
full_comparison_table = pd.DataFrame({
    "Model": [
        "Improved eLCS",
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        improved_accuracy,
        logistic_accuracy,
        decision_tree_accuracy,
        random_forest_accuracy
    ],
    "Precision": [
        improved_precision,
        logistic_precision,
        decision_tree_precision,
        random_forest_precision
    ],
    "Recall": [
        improved_recall,
        logistic_recall,
        decision_tree_recall,
        random_forest_recall
    ],
    "F1 Score": [
        improved_f1,
        logistic_f1,
        decision_tree_f1,
        random_forest_f1
    ],
    "Balanced Accuracy": [
        improved_balanced_accuracy,
        logistic_balanced_accuracy,
        decision_tree_balanced_accuracy,
        random_forest_balanced_accuracy
    ]
})

full_comparison_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       5         "Decision Tree",
#       6         "Random Forest"
#       7     ],
#       8     "Accuracy": [
# ----> 9         improved_accuracy,
#      10         logistic_accuracy,
#      11         decision_tree_accuracy,
#      12         random_forest_accuracy
#
# NameError: name 'improved_accuracy' is not defined

# %%
improved_metrics = pd.read_csv(
    "../results/improved_lcs/improved_lcs_metrics.csv"
)

improved_metrics
# Out:
#               Metric  Improved eLCS
# 0           Accuracy       0.768630
# 1          Precision       0.541522
# 2             Recall       0.836898
# 3           F1 Score       0.657563
# 4  Balanced Accuracy       0.790430

# %%
improved_accuracy = improved_metrics.loc[
    improved_metrics["Metric"] == "Accuracy",
    "Improved eLCS"
].iloc[0]

improved_precision = improved_metrics.loc[
    improved_metrics["Metric"] == "Precision",
    "Improved eLCS"
].iloc[0]

improved_recall = improved_metrics.loc[
    improved_metrics["Metric"] == "Recall",
    "Improved eLCS"
].iloc[0]

improved_f1 = improved_metrics.loc[
    improved_metrics["Metric"] == "F1 Score",
    "Improved eLCS"
].iloc[0]

improved_balanced_accuracy = improved_metrics.loc[
    improved_metrics["Metric"] == "Balanced Accuracy",
    "Improved eLCS"
].iloc[0]

print("Improved eLCS metrics loaded successfully.")
# Out:
# Improved eLCS metrics loaded successfully.

# %%
full_comparison_table = pd.DataFrame({
    "Model": [
        "Improved eLCS",
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "Accuracy": [
        improved_accuracy,
        logistic_accuracy,
        decision_tree_accuracy,
        random_forest_accuracy
    ],
    "Precision": [
        improved_precision,
        logistic_precision,
        decision_tree_precision,
        random_forest_precision
    ],
    "Recall": [
        improved_recall,
        logistic_recall,
        decision_tree_recall,
        random_forest_recall
    ],
    "F1 Score": [
        improved_f1,
        logistic_f1,
        decision_tree_f1,
        random_forest_f1
    ],
    "Balanced Accuracy": [
        improved_balanced_accuracy,
        logistic_balanced_accuracy,
        decision_tree_balanced_accuracy,
        random_forest_balanced_accuracy
    ]
})

full_comparison_table
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0        Improved eLCS  0.768630   0.541522  0.836898  0.657563
# 1  Logistic Regression  0.739532   0.505942  0.796791  0.618899
# 2        Decision Tree  0.761533   0.551913  0.540107  0.545946
# 3        Random Forest  0.836054   0.703704  0.660428  0.681379
#
#    Balanced Accuracy
# 0           0.790430
# 1           0.757816
# 2           0.690826
# 3           0.779972

# %%
from pathlib import Path

comparison_dir = Path("../results/model_comparison")

comparison_dir.mkdir(
    parents=True,
    exist_ok=True
)

full_comparison_table.to_csv(
    comparison_dir / "model_comparison_results.csv",
    index=False
)

print("Model comparison exported.")
# Out:
# Model comparison exported.
